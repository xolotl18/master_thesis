# %%
import csv
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_pareto_frontier(Xs, Ys, names, title, maxX=True, maxY=True):
    '''Pareto frontier selection process'''
    sorted_list = sorted([[Xs[i], Ys[i], names[i]] for i in range(len(Xs))], reverse=maxY, key=lambda x: x[:1])
    pareto_front = [sorted_list[0]]
    for pair in sorted_list[1:]:
        if maxY:
            if pair[1] >= pareto_front[-1][1]:
                pareto_front.append(pair)
        else:
            if pair[1] <= pareto_front[-1][1]:
                pareto_front.append(pair)
    
    '''Plotting process'''
    plt.rcParams["figure.figsize"] = (20,20)
    plt.rcParams.update({'font.size': 22})
    plt.scatter(Xs,Ys)
    pf_X = [pair[0] for pair in pareto_front]
    pf_Y = [pair[1] for pair in pareto_front]
    plt.plot(pf_X, pf_Y, marker = '.', markersize=18)
    plt.axhline(y=30, color='r', linestyle="dashed")
    plt.xlabel("IoU score")
    plt.ylabel("frames per second")
    
    for x, y, name in pareto_front:
        label = name

        plt.annotate(label, # this is the value which we want to label (text)
                     (x,y), # x and y is the points location where we have to label
                     textcoords="offset points",
                     xytext=(0,10), # this for the distance between the points
                     # and the text label
                     ha='center',
                     arrowprops=dict(arrowstyle="->", color='red')
                     )
    plt.savefig(title, dpi=160, bbox_inches='tight')
    plt.show()

# %%
file = open("stage1.csv")
reader = csv.reader(file)
title = "stage1.png"
ious = []
fps = []
names = []
for i, row in enumerate(reader):
    if i==0:
        continue
    ious.append(float(row[7]))
    fps.append(float(row[6]))
    names.append(str(row[0]))

plot_pareto_frontier(ious, fps, names, title)

# %%
file = open("stage1_bis.csv")
reader = csv.reader(file, delimiter=';')
title = "stage1_bis.png"
ious = []
fps = []
names = []
for i, row in enumerate(reader):
    if i==0:
        continue
    ious.append(float(row[8]))
    fps.append(float(row[7]))
    names.append(str(row[0]))

plot_pareto_frontier(ious, fps, names, title)

# %%
file = open("stage2.csv")
title = "stage2.png"
reader = csv.reader(file)
ious = []
fps = []
names = []
for i, row in enumerate(reader):
    if i==0:
        continue
    ious.append(float(row[7]))
    fps.append(float(row[6]))
    names.append(str(row[0]))

plot_pareto_frontier(ious, fps, names, title)

# %%
file = open("stage1_2.csv")
title = "stage1_2.png"
reader = csv.reader(file)
title = "stage1_2.png"
ious = []
fps = []
names = []
for i, row in enumerate(reader):
    if i==0:
        continue
    ious.append(float(row[7]))
    fps.append(float(row[6]))
    names.append(str(row[0]))

plot_pareto_frontier(ious, fps, names, title)

# %%
file = open("stage3.csv")
title = "stage3.png"
reader = csv.reader(file)
ious = []
fps = []
names = []
for i, row in enumerate(reader):
    if i==0:
        continue
    ious.append(float(row[7]))
    fps.append(float(row[6]))
    names.append(str(row[0]))

plot_pareto_frontier(ious, fps, names, title)

# %%
file = open("stage1_2_3.csv")
title = "stage1_2_3.png"
reader = csv.reader(file)
ious = []
fps = []
names = []
for i, row in enumerate(reader):
    if i==0:
        continue
    ious.append(float(row[7]))
    fps.append(float(row[6]))
    names.append(str(row[0]))

plot_pareto_frontier(ious, fps, names, title)

# %%
file = open("stage4_no_pt.csv")
reader = csv.reader(file)
title = "stage4_no_pt.png"
ious = []
fps = []
names = []
for i, row in enumerate(reader):
    if i==0:
        continue
    ious.append(float(row[4]))
    fps.append(float(row[3]))
    names.append(str(row[0])+"x"+str(row[1]))

plot_pareto_frontier(ious, fps, names, title)

# %%
file = open("stage4_pt.csv")
title = "stage4_pt.png"
reader = csv.reader(file)
ious = []
fps = []
names = []
for i, row in enumerate(reader):
    if i==0:
        continue
    ious.append(float(row[4]))
    fps.append(float(row[3]))
    names.append(str(row[0])+"x"+str(row[1]))
    
plot_pareto_frontier(ious, fps, names, title)

# %%
file = open("stage4_all.csv")
reader = csv.reader(file)
title = "stage4_all.png"
ious = []
fps = []
names = []
for i, row in enumerate(reader):
    if i==0:
        continue
    ious.append(float(row[4]))
    fps.append(float(row[3]))
    names.append(str(row[0]))

plot_pareto_frontier(ious, fps, names, title)

# %%
file = open("stage5.csv")
title = "stage5.png"
reader = csv.reader(file)
ious = []
fps = []
names = []
for i, row in enumerate(reader):
    if i==0:
        continue
    ious.append(float(row[4]))
    fps.append(float(row[3]))
    names.append(str(row[0])+"x"+str(row[1]))

plot_pareto_frontier(ious, fps, names, title)

# %%
file = open("stage4_5.csv")
title = "stage4_5.png"
reader = csv.reader(file)
ious = []
fps = []
names = []
for i, row in enumerate(reader):
    if i==0:
        continue
    ious.append(float(row[4]))
    fps.append(float(row[3]))
    names.append(str(row[0])+"x"+str(row[1]))

plot_pareto_frontier(ious, fps, names, title)

# %%
file = open("stage1_5.csv")
title = "stage1_5.png"
reader = csv.reader(file)
ious = []
fps = []
names = []
for i, row in enumerate(reader):
    if i==0:
        continue
    ious.append(float(row[7]))
    fps.append(float(row[6]))
    names.append(str(row[0]))

plot_pareto_frontier(ious, fps, names, title)

# %%
file = open("stage_overall.csv")
reader = csv.reader(file)
title = "stage_overall.png"
ious = []
fps = []
names = []
for i, row in enumerate(reader):
    if i==0:
        continue
    ious.append(float(row[9].replace(",", ".")))
    fps.append(float(row[8].replace(",", ".")))
    names.append(str(row[0].replace(",", ".")))

plot_pareto_frontier(ious, fps, names, title)
