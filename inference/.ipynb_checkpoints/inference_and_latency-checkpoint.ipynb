# %%
#this program has to load images from memory, initialize an onnx session with the pretrained and pre-exported onnx model and then
#then it has to perform the inference on all the images in the test set and compute the iou score
import os
import time
import numpy as np
import onnx
import onnxruntime
import torch
import torch.nn as nn
import torch.optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as T
from torchmetrics import JaccardIndex
from statistics import mean
import albumentations as A
from albumentations.pytorch import ToTensorV2
import cv2
import matplotlib.pyplot as plt
import sys

c_dir = os.getcwd()
mt_dir = os.path.dirname(c_dir)
models_path = os.path.join(mt_dir, "models")
sys.path.insert(1, models_path)
from fast_scnn import FastSCNN

batch_size = 1
num_workers = 1

class PackagesInferenceDataset(Dataset):
    def __init__(self, images_filenames, images_directory, masks_directory, transform=None,):
        self.images_filenames = images_filenames
        self.images_directory = images_directory
        self.masks_directory = masks_directory
        self.transform = transform

    def __len__(self):
        return len(self.images_filenames)

    def __getitem__(self, idx):
        image_filename = self.images_filenames[idx]
        image = cv2.imread(os.path.join(self.images_directory, image_filename))
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(
            os.path.join(self.masks_directory, image_filename), cv2.IMREAD_UNCHANGED,
        )
        mask = mask.astype(np.float32)
        mask[mask == 0.0] = 0.0
        mask[mask == 255.0] = 1.0
        original_size = tuple(image.shape[:2])
        if self.transform is not None:
            transformed = self.transform(image=image, mask=mask)
            image = transformed["image"]
            mask = transformed["mask"]
        return image, mask, original_size

test_transform = A.Compose(
    [
        A.Resize(512, 512),
        A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
        ToTensorV2(),
    ]
)

test_images_path = os.path.join(mt_dir, "full_dataset/test/images")
test_label_path = os.path.join(mt_dir, "full_dataset/test/labels")
test_images_filenames = [item for item in os.listdir(test_images_path) if item.endswith(".png")]
test_dataset = PackagesInferenceDataset(images_filenames=test_images_filenames, images_directory=test_images_path, masks_directory=test_label_path, transform=test_transform)

test_im = test_dataset[0][0].unsqueeze(0)
test_mask = test_dataset[0][1]
onnx_path = os.path.join(mt_dir, "model_checkpoints/fast_scnn300e_noinit.onnx")
onnx_model = onnx.load(onnx_path)
onnx.checker.check_model(onnx_model)
ort_session = onnxruntime.InferenceSession(onnx_path)

def to_numpy(tensor):
    return tensor.detach().cpu().numpy() if tensor.requires_grad else tensor.cpu().numpy()

# compute ONNX Runtime output prediction
ort_inputs = {ort_session.get_inputs()[0].name: to_numpy(test_im)}
ort_outs = ort_session.run(None, ort_inputs) 
print()

#inference over the entire test dataset one image at a time
latency_onnx = []
i = 0
for image, mask, (height, width) in test_dataset:
    image = image.unsqueeze(0)
    ort_inputs = {ort_session.get_inputs()[0].name: to_numpy(image)}
    i+=1
    start = time.time()
    ort_outs = ort_session.run(None, ort_inputs)
    lat = time.time()-start
    latency_onnx.append(lat)
    print(f"inference latency on image {i} is {lat}")
# Out:
# inference latency on image 1 is 0.0074176788330078125
# inference latency on image 2 is 0.0068318843841552734
# inference latency on image 3 is 0.007146358489990234
# inference latency on image 4 is 0.00716400146484375
# inference latency on image 5 is 0.007811069488525391
# inference latency on image 6 is 0.00801539421081543
# inference latency on image 7 is 0.007949590682983398
# inference latency on image 8 is 0.00807046890258789
# inference latency on image 9 is 0.00961446762084961
# inference latency on image 10 is 0.008406877517700195
# inference latency on image 11 is 0.008008718490600586
# inference latency on image 12 is 0.00770115852355957
# inference latency on image 13 is 0.0077342987060546875
# inference latency on image 14 is 0.007765769958496094
# inference latency on image 15 is 0.007076263427734375
# inference latency on image 16 is 0.007718563079833984
# inference latency on image 17 is 0.00793004035949707
# inference latency on image 18 is 0.007266044616699219
# inference latency on image 19 is 0.007853984832763672
# inference latency on image 20 is 0.007498025894165039
# inference latency on image 21 is 0.007497310638427734
# inference latency on image 22 is 0.007857561111450195
# inference latency on image 23 is 0.007503986358642578
# inference latency on image 24 is 0.0071790218353271484
# inference latency on image 25 is 0.007482767105102539
# inference latency on image 26 is 0.007144927978515625
# inference latency on image 27 is 0.0073893070220947266
# inference latency on image 28 is 0.0075571537017822266
# inference latency on image 29 is 0.00742340087890625
# inference latency on image 30 is 0.0070340633392333984
# inference latency on image 31 is 0.007770538330078125
# inference latency on image 32 is 0.008886575698852539
# inference latency on image 33 is 0.008509397506713867
# inference latency on image 34 is 0.008927106857299805
# inference latency on image 35 is 0.008359432220458984
# inference latency on image 36 is 0.008733749389648438
# inference latency on image 37 is 0.007754802703857422
# inference latency on image 38 is 0.00875544548034668
# inference latency on image 39 is 0.008313179016113281
# inference latency on image 40 is 0.008809089660644531
# inference latency on image 41 is 0.008169412612915039
# inference latency on image 42 is 0.00787353515625
# inference latency on image 43 is 0.00838923454284668
# inference latency on image 44 is 0.008095264434814453
# inference latency on image 45 is 0.009021282196044922
# inference latency on image 46 is 0.00896310806274414
# inference latency on image 47 is 0.0076961517333984375
# inference latency on image 48 is 0.008274316787719727
# inference latency on image 49 is 0.008244514465332031
# inference latency on image 50 is 0.008399724960327148
# inference latency on image 51 is 0.008434534072875977
# inference latency on image 52 is 0.008867979049682617
# inference latency on image 53 is 0.008471012115478516
# inference latency on image 54 is 0.009378671646118164
# inference latency on image 55 is 0.008305549621582031
# inference latency on image 56 is 0.008445501327514648
# inference latency on image 57 is 0.007762432098388672
# inference latency on image 58 is 0.0075228214263916016
# inference latency on image 59 is 0.0075685977935791016
# inference latency on image 60 is 0.007815122604370117

# %%
#let's compare onnx latency with pytorch model original latency
model_checkpoint = os.path.join(mt_dir, "model_checkpoints/fast_scnn300e.pt")

model = FastSCNN(in_channels=3, num_classes=1)
model.load_state_dict(torch.load(model_checkpoint, map_location=torch.device('cpu')))

latency_torch = []
i = 0
for image, mask, (height, width) in test_dataset:
    image = image.unsqueeze(0)
    i += 1
    start = time.time()
    output = model(image)
    lat = time.time()-start
    latency_torch.append(lat)
    print(f"inference latency on image {i} is {lat}")
# Out:
# inference latency on image 1 is 0.04911303520202637
# inference latency on image 2 is 0.03372359275817871
# inference latency on image 3 is 0.030426979064941406
# inference latency on image 4 is 0.029897689819335938
# inference latency on image 5 is 0.029914140701293945
# inference latency on image 6 is 0.03347277641296387
# inference latency on image 7 is 0.030281543731689453
# inference latency on image 8 is 0.029467105865478516
# inference latency on image 9 is 0.029593467712402344
# inference latency on image 10 is 0.030432701110839844
# inference latency on image 11 is 0.029616832733154297
# inference latency on image 12 is 0.029727935791015625
# inference latency on image 13 is 0.029143571853637695
# inference latency on image 14 is 0.02941274642944336
# inference latency on image 15 is 0.033174991607666016
# inference latency on image 16 is 0.0335235595703125
# inference latency on image 17 is 0.030449867248535156
# inference latency on image 18 is 0.031176328659057617
# inference latency on image 19 is 0.030474424362182617
# inference latency on image 20 is 0.030323266983032227
# inference latency on image 21 is 0.03395819664001465
# inference latency on image 22 is 0.02934575080871582
# inference latency on image 23 is 0.03023982048034668
# inference latency on image 24 is 0.03196597099304199
# inference latency on image 25 is 0.030373811721801758
# inference latency on image 26 is 0.03245377540588379
# inference latency on image 27 is 0.03151059150695801
# inference latency on image 28 is 0.03131461143493652
# inference latency on image 29 is 0.031356096267700195
# inference latency on image 30 is 0.030237197875976562
# inference latency on image 31 is 0.029404878616333008
# inference latency on image 32 is 0.032666683197021484
# inference latency on image 33 is 0.029108524322509766
# inference latency on image 34 is 0.02950453758239746
# inference latency on image 35 is 0.029072284698486328
# inference latency on image 36 is 0.029465675354003906
# inference latency on image 37 is 0.028739452362060547
# inference latency on image 38 is 0.029242515563964844
# inference latency on image 39 is 0.029644012451171875
# inference latency on image 40 is 0.029855966567993164
# inference latency on image 41 is 0.029947757720947266
# inference latency on image 42 is 0.030370473861694336
# inference latency on image 43 is 0.029022693634033203
# inference latency on image 44 is 0.029808759689331055
# inference latency on image 45 is 0.03015279769897461
# inference latency on image 46 is 0.029729127883911133
# inference latency on image 47 is 0.030241012573242188
# inference latency on image 48 is 0.029552459716796875
# inference latency on image 49 is 0.02952742576599121
# inference latency on image 50 is 0.029254913330078125
# inference latency on image 51 is 0.029105663299560547
# inference latency on image 52 is 0.03561878204345703
# inference latency on image 53 is 0.03272247314453125
# inference latency on image 54 is 0.035562753677368164
# inference latency on image 55 is 0.03378486633300781
# inference latency on image 56 is 0.0337827205657959
# inference latency on image 57 is 0.034117937088012695
# inference latency on image 58 is 0.03325676918029785
# inference latency on image 59 is 0.03315377235412598
# inference latency on image 60 is 0.03211402893066406

# %%
# compute ONNX Runtime output prediction
ort_inputs = {ort_session.get_inputs()[0].name: to_numpy(test_im)}
ort_outs = ort_session.run(None, ort_inputs) 
outs = np.array(ort_outs)
outs = outs.squeeze(0) #batch size
outs = outs.squeeze(0) #channels
outs = outs.squeeze(0) # 1 x h x w
outs = (outs >= 0.5) * 1
onnx_out = A.resize(
    outs, height=540, width=960, interpolation=cv2.INTER_NEAREST,
    )
print(onnx_out.shape)
plt.imshow(onnx_out)
# Out:
# (540, 960)

# %%
test_mask = test_mask.numpy()
test_mask = A.resize(
    test_mask, height=540, width=960, interpolation=cv2.INTER_NEAREST,
)
plt.imshow(test_mask)

# %%
test_image = test_im.squeeze(0).permute(1, 2, 0).numpy()
test_image = A.resize(
    test_image, height=540, width=960, interpolation=cv2.INTER_NEAREST,
    )
plt.imshow(test_image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
